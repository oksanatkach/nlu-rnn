# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
gru = pd.read_csv("../results/GRU-classifier-results-clean")
rnn = pd.read_csv("../results/RNN-classifier-results-clean")

# %%
gru
# Out:
#    hidden_units  accuracy
# 0            10     0.672
# 1            25     0.718
# 2            50     0.757

# %%
rnn
# Out:
#    hidden_units  accuracy
# 0            10     0.659
# 1            25     0.671
# 2            50     0.707

# %% [markdown]
# In both cases the performance improves as the number of hidden units increase. Maybe less overfitting as reasonable amount of training data. GRU performs better, as expected, as its architecture is better suited to modelling long distance dependencies.

# %%
data = {
    'Hidden Units': rnn.hidden_units,
    'RNN': rnn.accuracy,
    'GRU': gru.accuracy
}
df = pd.DataFrame(data)

# Convert the data to long format
df_long = df.melt(id_vars="Hidden Units", var_name="Model", value_name="Dev Set Accuracy")


sns.barplot(x='Hidden Units', y='Dev Set Accuracy', hue='Model', data=df_long)
ax = plt.gca()
ax.set_ylim([0.5, 0.8])
# plt.title("Model Performance with Number of Hidden Units")
for container in ax.containers:
    ax.bar_label(container)
ax.legend(title='')
plt.show()
